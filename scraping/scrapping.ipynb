# %% [markdown]
# ## LEKOUNDA NGOLO Mardochet Gédéon
# ### COOP Msc |DATA SCIENCE
# ### FINAL EXAMEN : DATA COLLECTION
# ### Date : 09-12-2025

# %% [markdown]
# #### DATABASE CONFIGURATION

# %%
import sqlite3
import pandas as pd
from requests import get
from bs4 import BeautifulSoup as bs

# %%
DB_PATH = "dog_annonces.db"

def setup_database(db_name="dog_annonces.db"):
    conn = sqlite3.connect(db_name)
    c = conn.cursor()
    
    # Création de la table
    c.execute('''
        CREATE TABLE IF NOT EXISTS announces_dogs (
            id INTEGER PRIMARY KEY AUTOINCREMENT,
            title TEXT,
            price INTEGER,
            location TEXT,
            image_url TEXT,
            product_url TEXT UNIQUE
        )
    ''')
    
    conn.commit()
    return conn

# %% [markdown]
# ### SCRAPPING WEB PAGES WITH BeautifulSoup

# %%
def scrape_page(page_number):
    url = f'https://sn.coinafrique.com/categorie/chiens?page={page_number}'
    res = get(url)
    soup = bs(res.content, "html.parser")

    containers = soup.select("div.card.ad__card") 

    data = []

    for container in containers:
        try:
            # extract listing link
            a_tag = container.find("a", href=True)
            if not a_tag:
                continue

            product_url = "https://sn.coinafrique.com" + a_tag["href"]

            # open detail page
            detail_res = get(product_url)
            soup_detail = bs(detail_res.content, 'html.parser')

            # title
            title_tag = soup_detail.find("h1")
            title = title_tag.get_text(strip=True) if title_tag else None

            # price
            price_tag = container.select_one("p.ad__card-price a")
            if price_tag:
                # Supprime 'CFA' et les espaces
                price_raw = price_tag.get_text(strip=True)
                price = price_raw.replace("CFA", "").replace(" ", "")
            else:
                price = None

            # location
            loc_span = container.select_one("p.ad__card-location span")
            location = loc_span.get_text(strip=True) if loc_span else None

            # images
            img_tag = soup_detail.find("img", class_="ad__card-img")
            if not img_tag:
                img_tag = soup_detail.find("img")
            image_link = img_tag["src"] if img_tag else None

            data.append({
                "title": title,
                "price": price,
                "location": location,
                "image": image_link,
                "url": product_url
            })

        except Exception as e:
            print("Error:", e)
            continue

    return data

# %%
df = pd.DataFrame()
for page in range(1, 3):
    print(f"Scraping page {page}...")
    page_data = scrape_page(page)
    if len(page_data) == 0:
        print("Probably empty page.")
        break
    df_page = pd.DataFrame(page_data)
    df = pd.concat([df, df_page], axis=0).reset_index(drop=True)
print("Scraping completed!") # For test need I scrapping only 4 pages#df.to_csv("coinafrique_apartments_raw.csv", index=False)
# Out:
# Scraping page 1...
# Scraping page 2...
# Scraping completed!

# %%
df
# Out:
#                           title           price                    location  \
# 0    Berger malinois charbonner             250              Thies, Sénégal
# 1          Chiot Bichon Maltais          100000    Almadies, Dakar, Sénégal
# 2    Chiots Labradors Retriever          300000  Guediawaye, Dakar, Sénégal
# 3                Chiot Malinois          200000              Dakar, Sénégal
# 4         Chiot Berger Malinois          150000  Almadies 2, Dakar, Sénégal
# ..                          ...             ...                         ...
# 163       Chiot Berger Allemand          130000              Niaga, Sénégal
# 164            Chiot Rottweiler             250              Dakar, Sénégal
# 165   Chiots labrador pure race  Prixsurdemande        Mbao, Dakar, Sénégal
# 166       Chiots Bichon Maltais  Prixsurdemande              Dakar, Sénégal
# 167     Berger allemand femelle          155000         Diamniadio, Sénégal
#
#                                                  image  \
# 0    https://static.coinafrique.com/static/images/p...
# 1    https://static.coinafrique.com/static/images/p...
# 2    https://static.coinafrique.com/static/images/p...
# 3    https://static.coinafrique.com/static/images/p...
# 4    https://static.coinafrique.com/static/images/p...
# ..                                                 ...
# 163  https://static.coinafrique.com/static/images/p...
# 164  https://static.coinafrique.com/static/images/p...
# 165  https://static.coinafrique.com/static/images/p...
# 166  https://static.coinafrique.com/static/images/p...
# 167  https://static.coinafrique.com/static/images/p...
#
#                                                    url
# 0    https://sn.coinafrique.com/annonce/chiens/berg...
# 1    https://sn.coinafrique.com/annonce/chiens/chio...
# 2    https://sn.coinafrique.com/annonce/chiens/chio...
# 3    https://sn.coinafrique.com/annonce/chiens/chio...
# 4    https://sn.coinafrique.com/annonce/chiens/chio...
# ..                                                 ...
# 163  https://sn.coinafrique.com/annonce/chiens/chio...
# 164  https://sn.coinafrique.com/annonce/chiens/chio...
# 165  https://sn.coinafrique.com/annonce/chiens/chio...
# 166  https://sn.coinafrique.com/annonce/chiens/chio...
# 167  https://sn.coinafrique.com/annonce/chiens/berg...
#
# [168 rows x 5 columns]

# %% [markdown]
# ### SCRAPPING WEB PAGES WITH BeautifulSoup (optimized version with sqlite)

# %%
def scrape_page_optimized(page_number):
    """
    Scrape la page de liste pour les annonces de chiens, en extrayant les données
    directement des cartes pour optimiser les performances.
    """
    base_url = "https://sn.coinafrique.com"
    list_url = f'{base_url}/categorie/chiens?page={page_number}'
    
    print(f"Scrapping de la page : {list_url}")
    
    try:
        res = get(list_url)
        res.raise_for_status() # raise bad requests HTTP code
    except Exception as e:
        print(f"Erreur lors de la requête de la page {page_number}: {e}")
        return []

    soup = bs(res.content, "html.parser")
    
    # REAL CSS CLASS FOR EACH AD PREVIEW
    containers = soup.select("div.card.ad__card") 
    print(f"Trouvé {len(containers)} annonces sur la page.")
    
    data = []

    for container in containers:
        try:
            # 1. Product Link & URL
            a_tag = container.find("a", href=True)
            if not a_tag:
                continue

            product_url = base_url + a_tag["href"]

            # 2. Title / Description
            # Found in <p class="ad__card-description">
            title_tag = container.select_one("p.ad__card-description a")
            title = title_tag.get_text(strip=True) if title_tag else None
            
            # 3. Price
            # Found in <p class="ad__card-price">
            price_tag = container.select_one("p.ad__card-price a")
            if price_tag:
                # delete 'CFA' and spaces
                price_raw = price_tag.get_text(strip=True)
                price = price_raw.replace("CFA", "").replace(" ", "")
            else:
                price = None

            # 4. Location (Adresse complète)
            # Found in <p class="ad__card-location">
            loc_span = container.select_one("p.ad__card-location span")
            location = loc_span.get_text(strip=True) if loc_span else None

            # 5. First Main Image
            # Found in <img class="ad__card-img">
            img_tag = container.find("img", class_="ad__card-img")
            image_link = img_tag["src"] if img_tag and "src" in img_tag.attrs else None

            data.append({
                "title": title,
                "price": price,
                "location": location,
                "image": image_link,
                "url": product_url
            })

        except Exception as e:
            # Affiche l'erreur mais continue le scrapping
            print(f"Erreur lors de l'extraction d'un élément: {e}")
            continue
            
    return data

# %%
data_page_1 = scrape_page_optimized(1)
print(data_page_1) # To verify the scraped data
# Out:
# Scrapping de la page : https://sn.coinafrique.com/categorie/chiens?page=1
# Trouvé 84 annonces sur la page.
# [{'title': 'Berger malinois charbonner', 'price': '250', 'location': 'Thies, Sénégal', 'image': 'https://images.coinafrique.com/thumb_5649558_uploaded_image1_1764572984.jpg', 'url': 'https://sn.coinafrique.com/annonce/chiens/berger-malinois-charbonner-5649558'}, {'title': 'Chiot Bichon Maltais', 'price': '100000', 'location': 'Almadies, Dakar, Sénégal', 'image': 'https://images.coinafrique.com/thumb_5644579_uploaded_image1_1764272051.jpg', 'url': 'https://sn.coinafrique.com/annonce/chiens/chiot-bichon-maltais-5644579'}, {'title': 'Chiots Labradors Retriever', 'price': '300000', 'location': 'Guediawaye, Dakar, Sénégal', 'image': 'https://images.coinafrique.com/thumb_5640905_uploaded_image1_1764096718.jpg', 'url': 'https://sn.coinafrique.com/annonce/chiens/chiots-labradors-retriever-5640905'}, {'title': 'Chiot Malinois', 'price': '200000', 'location': 'Dakar, Sénégal', 'image': 'https://images.coinafrique.com/thumb_5628892_uploaded_image1_1763507006.jpg', 'url': 'https://sn.coinafrique.com/annonce/chiens/chiot-malinois-5628892'}, {'title': 'Chiot Berger Malinois', 'price': '150000', 'location': 'Almadies 2, Dakar, Sénégal', 'image': 'https://images.coinafrique.com/thumb_5628715_uploaded_image1_1763500388.jpg', 'url': 'https://sn.coinafrique.com/annonce/chiens/chiot-berger-malinois-5628715'}, {'title': 'Chiot Husky', 'price': '350000', 'location': 'Sicap Liberté, Dakar, Sénégal', 'image': 'https://images.coinafrique.com/thumb_5621149_uploaded_image1_1763076045.jpg', 'url': 'https://sn.coinafrique.com/annonce/chiens/chiot-husky-5621149'}, {'title': 'Parfum Presa Canario', 'price': 'Prixsurdemande', 'location': 'Thies, Sénégal', 'image': 'https://images.coinafrique.com/thumb_5617572_uploaded_image1_1762928156.jpg', 'url': 'https://sn.coinafrique.com/annonce/chiens/parfum-presa-canario-5617572'}, {'title': 'Chiot Malinois', 'price': '125000', 'location': 'Mbao, Dakar, Sénégal', 'image': 'https://images.coinafrique.com/thumb_5616738_uploaded_image1_1762882607.jpg', 'url': 'https://sn.coinafrique.com/annonce/chiens/chiot-malinois-5616738'}, {'title': 'Chiots Border Collie', 'price': '140000', 'location': 'Almadies, Dakar, Sénégal', 'image': 'https://images.coinafrique.com/thumb_5616729_uploaded_image1_1762882207.jpg', 'url': 'https://sn.coinafrique.com/annonce/chiens/chiots-border-collie-5616729'}, {'title': 'Berger Belge Malinois', 'price': 'Prixsurdemande', 'location': 'Sicap Liberté, Dakar, Sénégal', 'image': 'https://images.coinafrique.com/thumb_5616008_uploaded_image1_1762860338.jpg', 'url': 'https://sn.coinafrique.com/annonce/chiens/berger-belge-malinois-5616008'}, {'title': 'Chiot', 'price': '70000', 'location': 'Dieuppeul-Derklé, Dakar, Sénégal', 'image': 'https://images.coinafrique.com/thumb_5613212_uploaded_image1_1762713775.jpg', 'url': 'https://sn.coinafrique.com/annonce/chiens/chiot-5613212'}, {'title': 'Chiot Pitbull Tricolor', 'price': '120000', 'location': 'Thies, Sénégal', 'image': 'https://images.coinafrique.com/thumb_5610458_uploaded_image1_1762521942.jpg', 'url': 'https://sn.coinafrique.com/annonce/chiens/chiot-pitbull-tricolor-5610458'}, {'title': 'Chiot Labrador', 'price': '400000', 'location': 'Sicap Liberté, Dakar, Sénégal', 'image': 'https://images.coinafrique.com/thumb_5603738_uploaded_image1_1762199868.jpg', 'url': 'https://sn.coinafrique.com/annonce/chiens/chiot-labrador-5603738'}, {'title': 'Chiot Bichon maltais', 'price': '125000', 'location': 'Mariste, Dakar, Sénégal', 'image': 'https://images.coinafrique.com/thumb_5601862_uploaded_image1_1762106679.jpg', 'url': 'https://sn.coinafrique.com/annonce/chiens/chiot-bichon-maltais-5601862'}, {'title': 'Chiot Pitbull', 'price': 'Prixsurdemande', 'location': 'Hann Bel-Air, Dakar, Sénégal', 'image': 'https://images.coinafrique.com/thumb_5599056_uploaded_image1_1761928314.jpg', 'url': 'https://sn.coinafrique.com/annonce/chiens/chiot-pitbull-5599056'}, {'title': 'Chiot American', 'price': '170', 'location': 'Thies, Sénégal', 'image': 'https://images.coinafrique.com ...

# %%
# --- 3. Main Function
def main_scraper(start_page=1, end_page=5):
    """
    Gère le flux de scraping, l'insertion dans la base de données et la fermeture.
    """
    # 1. DB configuration
    conn = setup_database()
    c = conn.cursor()
    
    total_inserted = 0
    total_skipped = 0
    
    for page in range(start_page, end_page + 1):
        # 2. Pages scraping
        ads_data = scrape_page_optimized(page)
        
        # 3. Data Insertion
        for ad in ads_data:
            # Using the IGNORE clause to avoid duplicates
            # (based on the 'product_url' column, which is UNIQUE)
            try:
                c.execute(
                    "INSERT OR IGNORE INTO announces_dogs (title, price, location, image_url, product_url) VALUES (:title, :price, :location, :image, :url)",
                    ad
                )
                if c.rowcount > 0:
                    total_inserted += 1
                else:
                    total_skipped += 1
                    
            except sqlite3.Error as e:
                print(f"Erreur SQLite lors de l'insertion: {e}")
        
        # saves changes for each pages
        conn.commit()
        
    print("\n" + "="*50)
    print(f"Scraping finished on {end_page - start_page + 1} pages.")
    print(f"Total inserted announces : {total_inserted}")
    print(f"Total ignored announces : {total_skipped}")
    
    # 4. close connexion
    conn.close()

# %%
# --- Execution ---
if __name__ == "__main__":
    main_scraper(start_page=1, end_page=5)
# Out:
# Scrapping de la page : https://sn.coinafrique.com/categorie/chiens?page=1
# Trouvé 84 annonces sur la page.
# Scrapping de la page : https://sn.coinafrique.com/categorie/chiens?page=2
# Trouvé 84 annonces sur la page.
# Scrapping de la page : https://sn.coinafrique.com/categorie/chiens?page=3
# Trouvé 84 annonces sur la page.
# Scrapping de la page : https://sn.coinafrique.com/categorie/chiens?page=4
# Trouvé 84 annonces sur la page.
# Scrapping de la page : https://sn.coinafrique.com/categorie/chiens?page=5
# Trouvé 84 annonces sur la page.
#
# ==================================================
# Scraping finished on 5 pages.
# Total inserted announces : 420
# Total ignored announces : 0

# %% [markdown]
# ### Scrapes data v2 for moutons_annonces

# %%
# --- 1. FONCTION DE CRÉATION DE LA BASE DE DONNÉES ---
def setup_database2(db_name="moutons_annonces.db"):
    conn = sqlite3.connect(db_name)
    c = conn.cursor()
    
    # Création de la table (maintenant pour les moutons)
    c.execute('''
        CREATE TABLE IF NOT EXISTS announces_moutons (
            id INTEGER PRIMARY KEY AUTOINCREMENT,
            name TEXT,
            price INTEGER,        
            address TEXT,         
            image_url TEXT,       
            product_url TEXT UNIQUE
        )
    ''')
    
    conn.commit()
    return conn

# %%
# --- 2. FONCTION DE SCRAPING OPTIMISÉE POUR LES MOUTONS ---
def scrape_moutons_page(page_number):
    """
    Scrape une page de liste Coinafrique pour les annonces de MOUTONS.
    """
    base_url = "https://sn.coinafrique.com"
    list_url = f'{base_url}/categorie/moutons?page={page_number}' # Changement ici
    
    print(f"Scrapping de la page : {list_url}")
    
    try:
        res = get(list_url)
        res.raise_for_status() 
    except Exception as e:
        print(f"Erreur lors de la requête de la page {page_number}: {e}")
        return []

    soup = bs(res.content, "html.parser")
    containers = soup.select("div.card.ad__card") 
    
    data = []

    for container in containers:
        try:
            # get URL of product
            a_tag = container.find("a", href=True)
            if not a_tag:
                continue
                
            product_url = base_url + a_tag["href"]
            
            # Name (Titre / Description)
            title_tag = container.select_one("p.ad__card-description a")
            name = title_tag.get_text(strip=True) if title_tag else None
            
            # Price (Prix)
            price_tag = container.select_one("p.ad__card-price a")
            price = None
            if price_tag:
                price_raw = price_tag.get_text(strip=True)
                # Nettoyage et conversion du prix
                price_str = price_raw.replace("CFA", "").replace(" ", "").strip()
                price = int(price_str) if price_str.isdigit() else None

            # Address (Localisation)
            loc_span = container.select_one("p.ad__card-location span")
            address = loc_span.get_text(strip=True) if loc_span else None

            # Image Link (Lien de l'image)
            img_tag = container.find("img", class_="ad__card-img")
            image_link = img_tag["src"] if img_tag and "src" in img_tag.attrs else None

            # Ajout des données sous forme de tuple pour l'insertion SQLite
            data.append((name, price, address, image_link, product_url))

        except Exception as e:
            print(f"Erreur lors de l'extraction d'un élément: {e}")
            continue
            
    return data

# %%
data_page_1 = scrape_moutons_page(1)
print(data_page_1) # To verify the scraped data
# Out:
# Scrapping de la page : https://sn.coinafrique.com/categorie/moutons?page=1
# [('Fauteuil pliable', 50000, 'Parcelle Assainies, Dakar, Sénégal', 'https://images.coinafrique.com/thumb_5641122_uploaded_image2_1764104086.jpeg', 'https://sn.coinafrique.com/annonce/moutons/fauteuil-pliable-5641122'), ('Agneau pur sang', None, 'Mbao, Dakar, Sénégal', 'https://images.coinafrique.com/thumb_5631456_uploaded_image1_1763631774.jpg', 'https://sn.coinafrique.com/annonce/moutons/agneau-pur-sang-5631456'), ('Mouton', 125000, 'Guediawaye, Dakar, Sénégal', 'https://images.coinafrique.com/thumb_5630109_uploaded_image1_1763563794.jpg', 'https://sn.coinafrique.com/annonce/moutons/mouton-5630109'), ('Mouton Ladoum', 800000, 'Guediawaye, Dakar, Sénégal', 'https://images.coinafrique.com/thumb_5630102_uploaded_image1_1763563551.jpg', 'https://sn.coinafrique.com/annonce/moutons/mouton-ladoum-5630102'), ('Moutons Ladoum', 350000, 'Thies, Sénégal', 'https://images.coinafrique.com/thumb_5613540_uploaded_image1_1762738491.jpg', 'https://sn.coinafrique.com/annonce/moutons/moutons-ladoum-5613540'), ('Mouton Ladoum', 1000000, 'Guediawaye, Dakar, Sénégal', 'https://images.coinafrique.com/thumb_5594186_uploaded_image1_1761667729.jpg', 'https://sn.coinafrique.com/annonce/moutons/mouton-ladoum-5594186'), ('Mouton ladoum', 1000000, 'Guediawaye, Dakar, Sénégal', 'https://images.coinafrique.com/thumb_5590609_uploaded_image1_1761399893.jpg', 'https://sn.coinafrique.com/annonce/moutons/mouton-ladoum-5590609'), ('Mouton Ladoum', 1000000, 'Guediawaye, Dakar, Sénégal', 'https://images.coinafrique.com/thumb_5571703_uploaded_image1_1760360461.jpg', 'https://sn.coinafrique.com/annonce/moutons/mouton-ladoum-5571703'), ('Mâles ladoum', 300000, 'Mbao, Dakar, Sénégal', 'https://images.coinafrique.com/thumb_5570235_uploaded_image1_1760269024.jpg', 'https://sn.coinafrique.com/annonce/moutons/males-ladoum-5570235'), ('Mouton', 200000, 'Pikine, Sénégal', 'https://images.coinafrique.com/thumb_5561288_uploaded_image1_1759765735.jpg', 'https://sn.coinafrique.com/annonce/moutons/mouton-5561288'), ('Mouton Ladoum', 250000, 'Mbour, Sénégal', 'https://images.coinafrique.com/thumb_5546272_uploaded_image1_1758985252.jpg', 'https://sn.coinafrique.com/annonce/moutons/mouton-ladoum-5546272'), ('Mouton', 200000, 'Guediawaye, Dakar, Sénégal', 'https://images.coinafrique.com/thumb_5543556_uploaded_image1_1758817920.jpg', 'https://sn.coinafrique.com/annonce/moutons/mouton-5543556'), ('Mouton', 550, 'Rufisque, Sénégal', 'https://images.coinafrique.com/thumb_5521645_uploaded_image1_1757668518.jpg', 'https://sn.coinafrique.com/annonce/moutons/mouton-5521645'), ('Mouton', 700000, 'Guediawaye, Dakar, Sénégal', 'https://images.coinafrique.com/thumb_5514422_uploaded_image1_1757326730.jpg', 'https://sn.coinafrique.com/annonce/moutons/mouton-5514422'), ('Mouton Ladoum', 800000, 'Thies, Sénégal', 'https://images.coinafrique.com/thumb_5513111_uploaded_image1_1757248013.jpg', 'https://sn.coinafrique.com/annonce/moutons/mouton-ladoum-5513111'), ('Mouton Ladoum', 800000, 'Malikounda, Sénégal', 'https://images.coinafrique.com/thumb_5454220_uploaded_image1_1754077895.jpg', 'https://sn.coinafrique.com/annonce/moutons/mouton-ladoum-5454220'), ('Mouton  ladoum', 550, 'Rufisque, Sénégal', 'https://images.coinafrique.com/thumb_5430741_uploaded_image1_1752926224.jpg', 'https://sn.coinafrique.com/annonce/moutons/mouton-ladoum-5430741'), ('Mouton  ladoum', 100000, 'Ouakam, Dakar, Sénégal', 'https://images.coinafrique.com/thumb_5416626_uploaded_image1_1752150844.jpg', 'https://sn.coinafrique.com/annonce/moutons/mouton-ladoum-5416626'), ('Mouton', 550000, 'Rufisque, Sénégal', 'https://images.coinafrique.com/thumb_5401936_uploaded_image1_1751443255.jpg', 'https://sn.coinafrique.com/annonce/moutons/mouton-5401936'), ('Ladoum Azowate', 125000, 'Ouakam, Dakar, Sénégal', 'https://images.coinafrique.com/thumb_5390051_uploaded_image1_1750779449.jpg', 'https://sn.coinafrique.com/annonce/moutons/ladoum-azowate-5390051'), ('Mouton Ladoum', 450000, 'Rufisque, Sénégal', 'https://images.coinafrique.com/thumb_53 ...

# %%
pd.DataFrame(data_page_1)
# Out:
#                    0          1                                   2  \
# 0   Fauteuil pliable    50000.0  Parcelle Assainies, Dakar, Sénégal
# 1    Agneau pur sang        NaN                Mbao, Dakar, Sénégal
# 2             Mouton   125000.0          Guediawaye, Dakar, Sénégal
# 3      Mouton Ladoum   800000.0          Guediawaye, Dakar, Sénégal
# 4     Moutons Ladoum   350000.0                      Thies, Sénégal
# ..               ...        ...                                 ...
# 79       Landoum pur  1200000.0                      Dakar, Sénégal
# 80     Mouton Ladoum   800000.0    Dieuppeul-Derklé, Dakar, Sénégal
# 81     Mouton Ladoum   350000.0                      Mbour, Sénégal
# 82        Ladoum Mix   250000.0              Ouakam, Dakar, Sénégal
# 83            Mouton    75000.0                Yoff, Dakar, Sénégal
#
#                                                     3  \
# 0   https://images.coinafrique.com/thumb_5641122_u...
# 1   https://images.coinafrique.com/thumb_5631456_u...
# 2   https://images.coinafrique.com/thumb_5630109_u...
# 3   https://images.coinafrique.com/thumb_5630102_u...
# 4   https://images.coinafrique.com/thumb_5613540_u...
# ..                                                ...
# 79  https://images.coinafrique.com/thumb_4948067_u...
# 80  https://images.coinafrique.com/thumb_4931367_u...
# 81  https://images.coinafrique.com/thumb_4905476_u...
# 82  https://images.coinafrique.com/thumb_4885680_u...
# 83  https://images.coinafrique.com/thumb_4879970_u...
#
#                                                     4
# 0   https://sn.coinafrique.com/annonce/moutons/fau...
# 1   https://sn.coinafrique.com/annonce/moutons/agn...
# 2   https://sn.coinafrique.com/annonce/moutons/mou...
# 3   https://sn.coinafrique.com/annonce/moutons/mou...
# 4   https://sn.coinafrique.com/annonce/moutons/mou...
# ..                                                ...
# 79  https://sn.coinafrique.com/annonce/moutons/lan...
# 80  https://sn.coinafrique.com/annonce/moutons/mou...
# 81  https://sn.coinafrique.com/annonce/moutons/mou...
# 82  https://sn.coinafrique.com/annonce/moutons/lad...
# 83  https://sn.coinafrique.com/annonce/moutons/mou...
#
# [84 rows x 5 columns]

# %%
# --- 3. Principal fonction of main scrape
def main_scraper2(start_page=1, end_page=3):
    """
    Gère le flux de scraping, l'insertion dans la base de données et la fermeture.
    """
    conn = setup_database2()
    c = conn.cursor()
    total_inserted = 0
    total_skipped = 0
    
    for page in range(start_page, end_page + 1):
        # 2. Scraping of page
        ads_data = scrape_moutons_page(page) #
        
        # 3.Data insertion
        for ad in ads_data:
            # IGNORE sql key word for avoid duplicated values
            try:
                # (name, price, address, image_url, product_url)
                c.execute('''
                    INSERT OR IGNORE INTO announces_moutons (name, price, address, image_url, product_url) 
                    VALUES (?, ?, ?, ?, ?)
                ''', ad)
                
                if c.rowcount > 0:
                    total_inserted += 1
                else:
                    total_skipped += 1
                    
            except sqlite3.Error as e:
                print(f"Erreur SQLite lors de l'insertion: {e}")
        
        conn.commit()
        
    print("\n" + "="*50)
    print(f"Scraping des moutons finished on {end_page - start_page + 1} pages.")
    print(f"Total inserted annonces : {total_inserted}")
    print(f"Total ignored announces(doublicated) : {total_skipped}")
    
    # 4. Closed connexion
    conn.close()

# %%
if __name__ == "__main__":
    main_scraper2(start_page=1, end_page=5)
# Out:
# Scrapping de la page : https://sn.coinafrique.com/categorie/moutons?page=1
# Scrapping de la page : https://sn.coinafrique.com/categorie/moutons?page=2
# Scrapping de la page : https://sn.coinafrique.com/categorie/moutons?page=3
# Scrapping de la page : https://sn.coinafrique.com/categorie/moutons?page=4
# Scrapping de la page : https://sn.coinafrique.com/categorie/moutons?page=5
#
# ==================================================
# Scraping des moutons finished on 5 pages.
# Total inserted annonces : 420
# Total ignored announces(doublicated) : 0

# %% [markdown]
# ### Scrapping data (autres-animaux)

# %%
# --- 1. FONCTION DE CRÉATION DE LA BASE DE DONNÉES ---
def setup_database3(db_name="autres_animaux_annonces.db"):
    """
    Crée la base de données SQLite et la table 'annonces' si elles n'existent pas.
    """
    conn = sqlite3.connect(db_name)
    c = conn.cursor()
    
    c.execute('''
        CREATE TABLE IF NOT EXISTS other_announces (
            id INTEGER PRIMARY KEY AUTOINCREMENT,
            name TEXT,            
            price INTEGER,        
            address TEXT,         
            image_url TEXT,       
            product_url TEXT UNIQUE
        )
    ''')
    conn.commit()
    return conn

# %%
# ---  AGAIN SAME THINGS FOR THIS ONE 
def scrape_autres_animaux_page(page_number):
    """
    Scrape une page de liste pour les annonces d'AUTRES ANIMAUX.
    """
    base_url = "https://sn.coinafrique.com"
    list_url = f'{base_url}/categorie/autres-animaux?page={page_number}' 
    
    print(f"Scrapping de la page : {list_url}")
    
    try:
        res = get(list_url)
        res.raise_for_status() 
    except Exception as e:
        print(f"Erreur lors de la requête de la page {page_number}: {e}")
        return []

    soup = bs(res.content, "html.parser")
    containers = soup.select("div.card.ad__card") 
    
    data = []

    for container in containers:
        try:
            #Get URL of product
            a_tag = container.find("a", href=True)
            if not a_tag:
                continue
                
            product_url = base_url + a_tag["href"]
            
            # Name (Titre / Description dans le site)
            title_tag = container.select_one("p.ad__card-description a")
            name = title_tag.get_text(strip=True) if title_tag else None
            
            # Price (Prix)
            price_tag = container.select_one("p.ad__card-price a")
            price = None
            if price_tag:
                price_raw = price_tag.get_text(strip=True)
                # Nettoyage et conversion du prix en entier
                price_str = price_raw.replace("CFA", "").replace(" ", "").strip()
                price = int(price_str) if price_str.isdigit() else None

            # Address (Localisation)
            loc_span = container.select_one("p.ad__card-location span")
            address = loc_span.get_text(strip=True) if loc_span else None

            # image Link 
            img_tag = container.find("img", class_="ad__card-img")
            image_link = img_tag["src"] if img_tag and "src" in img_tag.attrs else None
            data.append((name, price, address, image_link, product_url))

        except Exception as e:
            print(f"Erreur lors de l'extraction d'un élément: {e}")
            continue
            
    return data

# %%
# --- 3. FONCTION PRINCIPALE D'EXÉCUTION ET D'INSERTION ---
def main_scraper3(start_page=1, end_page=3):
    """
    Gère le flux de scraping pour les Autres Animaux, l'insertion dans la base de données et la fermeture.
    """
    # 1. Configuration de la DB (fichier 'autres_animaux_annonces.db')
    conn = setup_database3()
    c = conn.cursor()
    
    total_inserted = 0
    total_skipped = 0
    
    for page in range(start_page, end_page + 1):
        # 2. Scraping pages
        ads_data = scrape_autres_animaux_page(page) 
        
        # 3. Insertion data
        for ad in ads_data:
            try:
                c.execute('''
                    INSERT OR IGNORE INTO other_announces (name, price, address, image_url, product_url) 
                    VALUES (?, ?, ?, ?, ?)
                ''', ad)
                
                if c.rowcount > 0:
                    total_inserted += 1
                else:
                    total_skipped += 1
                    
            except sqlite3.Error as e:
                print(f"Erreur SQLite lors de l'insertion: {e}")
        
        # SChange saves
        conn.commit()
        
    print("\n" + "="*50)
    print(f"Scraping des Autres Animaux terminé sur {end_page - start_page + 1} pages.")
    print(f"Total d'annonces insérées : {total_inserted}")
    print(f"Total d'annonces ignorées (doublons) : {total_skipped}")
    
    # 4. Fermeture de la connexion
    conn.close()

# %%
# --- Exécution ---
if __name__ == "__main__":
    main_scraper3(start_page=1, end_page=5)
# Out:
# Scrapping de la page : https://sn.coinafrique.com/categorie/autres-animaux?page=1
# Scrapping de la page : https://sn.coinafrique.com/categorie/autres-animaux?page=2
# Scrapping de la page : https://sn.coinafrique.com/categorie/autres-animaux?page=3
# Scrapping de la page : https://sn.coinafrique.com/categorie/autres-animaux?page=4
# Scrapping de la page : https://sn.coinafrique.com/categorie/autres-animaux?page=5
#
# ==================================================
# Scraping des Autres Animaux terminé sur 5 pages.
# Total d'annonces insérées : 420
# Total d'annonces ignorées (doublons) : 0

# %% [markdown]
# ### Scrappe data (pigeons et lapins)

# %%
# --- 1. FONCTION DE CRÉATION DE LA BASE DE DONNÉES ---
def setup_database4(db_name="ppige_annonces.db"):
    """
    Crée la base de données SQLite et la table 'annonces' si elles n'existent pas.
    """
    conn = sqlite3.connect(db_name)
    c = conn.cursor()
    
    c.execute('''
        CREATE TABLE IF NOT EXISTS pp_annonces (
            id INTEGER PRIMARY KEY AUTOINCREMENT,
            name TEXT,            
            price INTEGER,        
            address TEXT,         
            image_url TEXT,       
            product_url TEXT UNIQUE
        )
    ''')
    conn.commit()
    return conn

# %%
# --- 2. FONCTION DE SCRAPING OPTIMISÉE POUR LA VOLAILLE ---
def scrape_volaille_page(page_number):
    """
    Scrape une page de liste Coinafrique pour les annonces de Poules, Lapins et Pigeons.
    """
    base_url = "https://sn.coinafrique.com"
    list_url = f'{base_url}/categorie/poules-lapins-et-pigeons?page={page_number}' 
    
    print(f"Scrapping de la page : {list_url}")
    
    try:
        res = get(list_url)
        res.raise_for_status() 
    except Exception as e:
        print(f"Erreur lors de la requête de la page {page_number}: {e}")
        return []

    soup = bs(res.content, "html.parser")
    containers = soup.select("div.card.ad__card") 
    
    data = []

    for container in containers:
        try:
            a_tag = container.find("a", href=True)
            if not a_tag:
                continue
                
            product_url = base_url + a_tag["href"]
            
            # Name (Titre / Description)
            title_tag = container.select_one("p.ad__card-description a")
            name = title_tag.get_text(strip=True) if title_tag else None
            
            # Price 
            price_tag = container.select_one("p.ad__card-price a")
            price = None
            if price_tag:
                price_raw = price_tag.get_text(strip=True)
                price_str = price_raw.replace("CFA", "").replace(" ", "").strip()
                price = int(price_str) if price_str.isdigit() else None

            # Address (Localisation)
            loc_span = container.select_one("p.ad__card-location span")
            address = loc_span.get_text(strip=True) if loc_span else None

            # Image Link (Lien de l'image)
            img_tag = container.find("img", class_="ad__card-img")
            image_link = img_tag["src"] if img_tag and "src" in img_tag.attrs else None

            data.append((name, price, address, image_link, product_url))

        except Exception as e:
            print(f"Erreur lors de l'extraction d'un élément: {e}")
            continue
            
    return data

# %%
# --- 3. FONCTION PRINCIPALE D'EXÉCUTION ET D'INSERTION ---
def main_scraper4(start_page=1, end_page=3):
    """
    Gère le flux de scraping, l'insertion dans la base de données et la fermeture.
    """
    # 1. Configuration de la DB (fichier 'poules_lapins_pigeons_annonces.db')
    conn = setup_database4()
    c = conn.cursor()
    
    total_inserted = 0
    total_skipped = 0
    
    for page in range(start_page, end_page + 1):
        # 2. Scraping de la page
        ads_data = scrape_volaille_page(page) 
        
        # 3. Insertion des données
        for ad in ads_data:
            # Utilisation de INSERT OR IGNORE pour éviter les doublons
            try:
                c.execute('''
                    INSERT OR IGNORE INTO pp_annonces (name, price, address, image_url, product_url) 
                    VALUES (?, ?, ?, ?, ?)
                ''', ad)
                
                if c.rowcount > 0:
                    total_inserted += 1
                else:
                    total_skipped += 1
                    
            except sqlite3.Error as e:
                print(f"Erreur SQLite lors de l'insertion: {e}")
        
        # Sauvegarde les changements après chaque page
        conn.commit()
        
    print("\n" + "="*50)
    print(f"Scraping des Poules, Lapins et Pigeons terminé sur {end_page - start_page + 1} pages.")
    print(f"Total d'annonces insérées : {total_inserted}")
    print(f"Total d'annonces ignorées (doublons) : {total_skipped}")
    
    # 4. close connexion
    conn.close()

# %%
main_scraper4(start_page=1, end_page=5)
# Out:
# Scrapping de la page : https://sn.coinafrique.com/categorie/poules-lapins-et-pigeons?page=1
# Scrapping de la page : https://sn.coinafrique.com/categorie/poules-lapins-et-pigeons?page=2
# Scrapping de la page : https://sn.coinafrique.com/categorie/poules-lapins-et-pigeons?page=3
# Scrapping de la page : https://sn.coinafrique.com/categorie/poules-lapins-et-pigeons?page=4
# Scrapping de la page : https://sn.coinafrique.com/categorie/poules-lapins-et-pigeons?page=5
#
# ==================================================
# Scraping des Poules, Lapins et Pigeons terminé sur 5 pages.
# Total d'annonces insérées : 168
# Total d'annonces ignorées (doublons) : 252

# %% [markdown]
# ## Cleaning data steps (for all of dataframes)

# %%
db_name = "ppige_annonces.db"
conn = sqlite3.connect(db_name)

# 2. Load data in DataFrame
df_panounces= pd.read_sql_query("SELECT * FROM pp_annonces", conn)

# 3. close connexion
conn.close()

print(f"DataFrame load {len(df_panounces)} rows.")
# Out:
# DataFrame load 420 rows.

# %%
df_panounces.drop_duplicates(inplace=True) 

print(f"Size of dataframe after suppression : {len(df_panounces )}")
# Out:
# Size of dataframe after suppression : 420

# %%
def extract_city(address):
    if pd.isna(address):
        return None
    parts = address.split(',')
    if len(parts) >= 2:
        return parts[1].strip()

    return address.strip() 

# Apply for new column'city'
df_panounces['city'] = df_panounces['address'].apply(extract_city)

# %%
print(df_panounces['city'].value_counts().head(10))
# Out:
# city
# Sénégal    234
# Dakar      186
# Name: count, dtype: int64

# %%
# Conversion finale en numérique (gère les cas où la DB aurait stocké des NaN comme chaînes)
# 'coerce' va remplacer les valeurs non numériques restantes par NaN
df_panounces['price'] = pd.to_numeric(df_panounces ['price'], errors='coerce') 

# Suppression des prix irréalistes (par exemple, prix égal à 0 ou négatif)
df.dropna(subset=['price'], inplace=True)

# %%
df_panounces['price'].fillna(df_panounces['price'].median(), inplace=True)
# Out:
# /tmp/ipykernel_27036/1512368334.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_panounces['price'].fillna(df_panounces['price'].median(), inplace=True)

# %%
df_panounces.dtypes
# Out:
# id               int64
# name            object
# price          float64
# address         object
# image_url       object
# product_url     object
# city            object
# dtype: object

# %%
df.isnull().sum()
# Out:
# title       0
# price       0
# location    0
# image       0
# url         0
# dtype: int64

# %%
print("\n" + "="*50)
print("Cleaning has done .")
print(f"final size cleaned : {len(df)}")
df_panounces.sample(20)
# Out:
# ==================================================
# Cleaning has done .
# final size cleaned : 168
#       id                      name     price  \
# 331  584                   Poulets    3500.0
# 142  143            Poussin Marans   10000.0
# 21    22   Pigeon Beauté Allemande   25000.0
# 9     10           Couple  Mondain  130000.0
# 239  240      Pigeon Padda de java   20000.0
# 289  542          Poulets de chair    3000.0
# 238  239              Pigeon Texan   70000.0
# 365  618             Pigeon dragon   20000.0
# 404  657                   Pigeons   25000.0
# 60    61         Lapin Californien  120000.0
# 336  589                    Poules    2800.0
# 252  505     Pigeons paons indiens   35000.0
# 213  214                     Lapin   30000.0
# 363  616        Coq Brahma Perdrix   35000.0
# 290  543              Couple texan   40000.0
# 396  649              Lapins nains   35000.0
# 172  173                  Lapereau   10000.0
# 134  135               Pigeon King   25000.0
# 229  230  Poulets brahman herminés  135000.0
# 414  667                    Poules    3000.0
#
#                                 address  \
# 331                      Dakar, Sénégal
# 142                      Dakar, Sénégal
# 21                       Thies, Sénégal
# 9                   HLM, Dakar, Sénégal
# 239             Point E, Dakar, Sénégal
# 289                      Dakar, Sénégal
# 238                      Mbour, Sénégal
# 365             Mariste, Dakar, Sénégal
# 404          Guediawaye, Dakar, Sénégal
# 60           Almadies 2, Dakar, Sénégal
# 336                      Dakar, Sénégal
# 252             Mariste, Dakar, Sénégal
# 213                      Niaga, Sénégal
# 363                      Mboro, Sénégal
# 290                      Thies, Sénégal
# 396                      Thies, Sénégal
# 172                      Niaga, Sénégal
# 134                      Dakar, Sénégal
# 229                      Dakar, Sénégal
# 414  Mermoz-Sacré Coeur, Dakar, Sénégal
#
#                                              image_url  \
# 331  https://images.coinafrique.com/thumb_3809817_u...
# 142  https://images.coinafrique.com/thumb_4603800_u...
# 21   https://images.coinafrique.com/thumb_5486666_u...
# 9    https://images.coinafrique.com/thumb_5541428_u...
# 239  https://images.coinafrique.com/thumb_4191356_u...
# 289  https://images.coinafrique.com/thumb_4021629_u...
# 238  https://images.coinafrique.com/thumb_4193114_u...
# 365  https://images.coinafrique.com/thumb_3671452_u...
# 404  https://images.coinafrique.com/thumb_3521128_u...
# 60   https://images.coinafrique.com/thumb_5189123_u...
# 336  https://images.coinafrique.com/thumb_3799302_u...
# 252  https://images.coinafrique.com/thumb_4155195_u...
# 213  https://images.coinafrique.com/thumb_4268327_u...
# 363  https://images.coinafrique.com/thumb_3671744_u...
# 290  https://images.coinafrique.com/thumb_4021335_u...
# 396  https://images.coinafrique.com/thumb_3537679_u...
# 172  https://images.coinafrique.com/thumb_4425850_u...
# 134  https://images.coinafrique.com/thumb_4624920_u...
# 229  https://images.coinafrique.com/thumb_4212808_u...
# 414  https://images.coinafrique.com/thumb_3447997_u...
#
#                                            product_url     city
# 331  https://sn.coinafrique.com/annonce/poules-lapi...  Sénégal
# 142  https://sn.coinafrique.com/annonce/poules-lapi...  Sénégal
# 21   https://sn.coinafrique.com/annonce/poules-lapi...  Sénégal
# 9    https://sn.coinafrique.com/annonce/poules-lapi...    Dakar
# 239  https://sn.coinafrique.com/annonce/poules-lapi...    Dakar
# 289  https://sn.coinafrique.com/annonce/poules-lapi...  Sénégal
# 238  https://sn.coinafrique.com/annonce/poules-lapi...  Sénégal
# 365  https://sn.coinafrique.com/annonce/poules-lapi...    Dakar
# 404  https://sn.coinafrique.com/annonce/poules-lapi...    Dakar
# 60   https://sn.coinafrique.com/annonce/poules-lapi...    Dakar
# 336  https://sn.coinafrique.com/annonce/poules-lapi...  Sénégal
# 252  https://sn.coinafrique.com/annonce/poules-lapi...    Dakar
# 213  https://sn.coinafrique.com/annonce/poules-lapi...  Sénégal
# 363  https://sn.coinafrique.com/annonce/poules-lapi...  Sénégal
# 290  https://sn.coinafrique.com/annonce/poules-lapi...  Sénégal
# 396  https://sn.coinafrique.com/annonce/poules-lapi...  Sénégal
# 172  https://sn.coinafrique.com/annonce/poules-lapi...  Sénégal
# 134  https://sn.coinafrique.com/annonce/poules-lapi...  Sénégal
# 229  https://sn.coinafrique.com/annonce/poules-lapi...  Sénégal
# 414  https://sn.coinafrique.com/annonce/poules-lapi...    Dakar

# %%
df.to_csv('ppigeons_clean.csv', index=False)

# %% [markdown]
# #### cleaning dog_annonces

# %%
db_name = "dog_annonces.db"
conn = sqlite3.connect(db_name)

# 2. Load data in DataFrame
df = pd.read_sql_query("SELECT * FROM announces_dogs", conn)

# 3. close connexion
conn.close()

print(f"DataFrame load {len(df_panounces )} rows.")
# Out:
# DataFrame load 420 rows.

# %%
df.drop_duplicates(inplace=True) 

print(f"Size of dataframe after suppression : {len(df)}")
# Out:
# Size of dataframe after suppression : 420

# %%
df['price'] = pd.to_numeric(df['price'], errors='coerce') 

df.dropna(subset=['price'], inplace=True)

df = df[df['price'] > 0]

df['price'] = df['price'].astype(float)

print("Colonne 'price' nettoyée et convertie en float.")
# Out:
# Colonne 'price' nettoyée et convertie en float.

# %%
df['price'].fillna(df['price'].median(), inplace=True)
# Out:
# /tmp/ipykernel_27036/1576110267.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['price'].fillna(df['price'].median(), inplace=True)

# %%
df.isnull().sum()
# Out:
# id             0
# title          0
# price          0
# location       0
# image_url      0
# product_url    0
# dtype: int64

# %%
print("\n" + "="*50)
print("Cleaning has done !.")
print(f"Final size of DataFrame cleaned : {len(df)}")
df.head()
# Out:
# ==================================================
# Cleaning has done !.
# Final size of DataFrame cleaned : 348
#    id                       title     price                    location  \
# 0   1  Berger malinois charbonner     250.0              Thies, Sénégal
# 1   2        Chiot Bichon Maltais  100000.0    Almadies, Dakar, Sénégal
# 2   3  Chiots Labradors Retriever  300000.0  Guediawaye, Dakar, Sénégal
# 3   4              Chiot Malinois  200000.0              Dakar, Sénégal
# 4   5       Chiot Berger Malinois  150000.0  Almadies 2, Dakar, Sénégal
#
#                                            image_url  \
# 0  https://images.coinafrique.com/thumb_5649558_u...
# 1  https://images.coinafrique.com/thumb_5644579_u...
# 2  https://images.coinafrique.com/thumb_5640905_u...
# 3  https://images.coinafrique.com/thumb_5628892_u...
# 4  https://images.coinafrique.com/thumb_5628715_u...
#
#                                          product_url
# 0  https://sn.coinafrique.com/annonce/chiens/berg...
# 1  https://sn.coinafrique.com/annonce/chiens/chio...
# 2  https://sn.coinafrique.com/annonce/chiens/chio...
# 3  https://sn.coinafrique.com/annonce/chiens/chio...
# 4  https://sn.coinafrique.com/annonce/chiens/chio...

# %%
# Sauvegarder les données nettoyées dans un nouveau fichier CSV
df.to_csv('dog_announces.csv', index=False)

# Sauvegarder les données nettoyées dans une nouvelle table
conn_cleaned = sqlite3.connect(db_name) 

#df.to_sql('annonces_cleaned', conn_cleaned, if_exists='replace', index=False)
#conn_cleaned.close()

# %% [markdown]
# ### cleaning moutons_annonces

# %%
db_name = "moutons_annonces.db"
conn = sqlite3.connect(db_name)

# 2. Load data in DataFrame
df = pd.read_sql_query("SELECT * FROM announces_moutons", conn)

# 3. close connexion
conn.close()

print(f"DataFrame load {len(df_panounces )} rows.")
# Out:
# DataFrame load 420 rows.

# %%
df.drop_duplicates(inplace=True) 

print(f"Size of dataframe after suppression : {len(df)}")
# Out:
# Size of dataframe after suppression : 420

# %%
df['price'] = pd.to_numeric(df['price'], errors='coerce') 

df.dropna(subset=['price'], inplace=True)

df = df[df['price'] > 0]

df['price'] = df['price'].astype(int)

print("Colonne 'price' nettoyée et convertie en entier.")
# Out:
# Colonne 'price' nettoyée et convertie en entier.

# %%
df.isnull().sum()
# Out:
# id             0
# name           0
# price          0
# address        0
# image_url      0
# product_url    0
# dtype: int64

# %%
print("\n" + "="*50)
print("Nettoyage terminé.")
print(f"Taille finale du DataFrame nettoyé : {len(df)}")
df.sample(10)
# Out:
# ==================================================
# Nettoyage terminé.
# Taille finale du DataFrame nettoyé : 351
#       id                     name    price                     address  \
# 23    24        Mouton de tabaski   200000      Ouakam, Dakar, Sénégal
# 405  406           Femelle ladoum  1000000  Guediawaye, Dakar, Sénégal
# 30    31                  Moutons   225000      Ouakam, Dakar, Sénégal
# 93    94                   Mouton   170000        Mbao, Dakar, Sénégal
# 351  352                   Mouton   100000             Pikine, Sénégal
# 65    66                   Bélier   225000  Guediawaye, Dakar, Sénégal
# 378  379            Mouton azawat   850000              Thies, Sénégal
# 73    74            Mouton Ladoum  1000000           Rufisque, Sénégal
# 294  295          Moutons tabaski   175000        Keur Massar, Sénégal
# 277  278  Moutons Jumeaux ladoums   600000              Niaga, Sénégal
#
#                                              image_url  \
# 23   https://images.coinafrique.com/thumb_5351264_u...
# 405  https://images.coinafrique.com/thumb_3695058_u...
# 30   https://images.coinafrique.com/thumb_5342599_u...
# 93   https://images.coinafrique.com/thumb_4785428_u...
# 351  https://images.coinafrique.com/thumb_3747590_u...
# 65   https://images.coinafrique.com/thumb_5179070_u...
# 378  https://images.coinafrique.com/thumb_3721884_u...
# 73   https://images.coinafrique.com/thumb_5026478_u...
# 294  https://images.coinafrique.com/thumb_3770483_u...
# 277  https://images.coinafrique.com/thumb_3911094_u...
#
#                                            product_url
# 23   https://sn.coinafrique.com/annonce/moutons/mou...
# 405  https://sn.coinafrique.com/annonce/moutons/fem...
# 30   https://sn.coinafrique.com/annonce/moutons/mou...
# 93   https://sn.coinafrique.com/annonce/moutons/mou...
# 351  https://sn.coinafrique.com/annonce/moutons/mou...
# 65   https://sn.coinafrique.com/annonce/moutons/bel...
# 378  https://sn.coinafrique.com/annonce/moutons/mou...
# 73   https://sn.coinafrique.com/annonce/moutons/mou...
# 294  https://sn.coinafrique.com/annonce/moutons/mou...
# 277  https://sn.coinafrique.com/annonce/moutons/mou...

# %%
df.to_csv('mouton_cleaned.csv', index=False)

# %% [markdown]
# ### cleaning autres_animaux

# %%
db_name = "autres_animaux_annonces.db"
conn = sqlite3.connect(db_name)

# 2. Load data in DataFrame
df = pd.read_sql_query("SELECT * FROM other_announces", conn)

# 3. close connexion
conn.close()

print(f"DataFrame load {len(df_panounces )} rows.")
# Out:
# DataFrame load 420 rows.

# %%
df.drop_duplicates(inplace=True) 

print(f"Size of dataframe after suppression : {len(df)}")
# Out:
# Size of dataframe after suppression : 420

# %%
df['price'] = pd.to_numeric(df['price'], errors='coerce') 

df.dropna(subset=['price'], inplace=True)

df = df[df['price'] > 0]

df['price'] = df['price'].astype(float)

print("Colonne 'price' nettoyée et convertie en float.")
# Out:
# Colonne 'price' nettoyée et convertie en entier.

# %%
df.isnull().sum()
# Out:
# id             0
# name           0
# price          0
# address        0
# image_url      0
# product_url    0
# dtype: int64

# %%
print("\n" + "="*50)
print("cleaning has done !.")
print(f"finale size of DataFrame nettoyé : {len(df)}")
df.head()
# Out:
# ==================================================
# cleaning has done !.
# finale size of DataFrame nettoyé : 329
#    id                           name      price                      address  \
# 1   2                        Taureau  2500000.0              Fatick, Sénégal
# 2   3                           Bœuf      650.0              Bambey, Sénégal
# 3   4                           Bœuf      725.0              Bambey, Sénégal
# 4   5                          Vache   350000.0  Patte d'oie, Dakar, Sénégal
# 7   8  Perroquets perruches ondulées    25000.0      Point E, Dakar, Sénégal
#
#                                            image_url  \
# 1  https://images.coinafrique.com/thumb_5634272_u...
# 2  https://images.coinafrique.com/thumb_5632019_u...
# 3  https://images.coinafrique.com/thumb_5632012_u...
# 4  https://images.coinafrique.com/thumb_5587581_u...
# 7  https://images.coinafrique.com/thumb_5560070_u...
#
#                                          product_url
# 1  https://sn.coinafrique.com/annonce/autres-anim...
# 2  https://sn.coinafrique.com/annonce/autres-anim...
# 3  https://sn.coinafrique.com/annonce/autres-anim...
# 4  https://sn.coinafrique.com/annonce/autres-anim...
# 7  https://sn.coinafrique.com/annonce/autres-anim...

# %%
df.to_csv('autres_animaus_cleaned.csv', index=False)
